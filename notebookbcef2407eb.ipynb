# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/limhongwei/deepfake4/sidset_subset_10000_binary/fake/fake_8915.png
# /kaggle/input/datasets/limhongwei/deepfake4/sidset_subset_10000_binary/fake/fake_4488.png
# /kaggle/input/datasets/limhongwei/deepfake4/sidset_subset_10000_binary/fake/fake_1157.png
# /kaggle/input/datasets/limhongwei/deepfake4/sidset_subset_10000_binary/fake/fake_9072.png
# /kaggle/input/datasets/limhongwei/deepfake4/sidset_subset_10000_binary/fake/fake_9980.png
# /kaggle/input/datasets/limhongwei/deepfake4/sidset_subset_10000_binary/fake/fake_8537.png
# /kaggle/input/datasets/limhongwei/deepfake4/sidset_subset_10000_binary/fake/fake_5227.png
# /kaggle/input/datasets/limhongwei/deepfake4/sidset_subset_10000_binary/fake/fake_0712.png
# /kaggle/input/datasets/limhongwei/deepfake4/sidset_subset_10000_binary/fake/fake_9819.png
# /kaggle/input/datasets/limhongwei/deepfake4/sidset_subset_10000_binary/fake/fake_7484.png
# ...

# %%
# %cd /kaggle/working/EE4002R-Deepfake-detection-Model
# !ls
# Out:
# [Errno 2] No such file or directory: '/kaggle/working/EE4002R-Deepfake-detection-Model'
# /kaggle/working
# __notebook__.ipynb

# %%
# !python /kaggle/working/EE4002R-Deepfake-detection-Model/train.py \
  --data_dir /kaggle/input/YOUR_DATASET_NAME/sidset_subset_10000_binary \
  --save_dir /kaggle/working/checkpoints \
  --save_name best_model.pth \
  --img_size 224 \
  --batch_size 8 \
  --epochs 8 \
  --warmup_epochs 3 \
  --lr 1e-5 \
  --dropout 0.4
# Out:
# python3: can't open file '/kaggle/working/EE4002R-Deepfake-detection-Model/train.py': [Errno 2] No such file or directory

# %%
# !git clone https://github.com/sukalemon/EE4002R-Deepfake-detection-Model.git
# Out:
# Cloning into 'EE4002R-Deepfake-detection-Model'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 20 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 16.40 KiB | 1.49 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd /kaggle/working/EE4002R-Deepfake-detection-Model
# !ls
# Out:
# /kaggle/working/EE4002R-Deepfake-detection-Model
# checkpoints  model.py  predict.py  README.md  requirements.txt	train.py

# %%
# !python train.py \
  --data_dir /kaggle/input/datasets/limhongwei/deepfake4/sidset_subset_10000_binary \
  --save_dir /kaggle/working/checkpoints \
  --save_name best_model.pth \
  --img_size 224 \
  --batch_size 8 \
  --epochs 8 \
  --warmup_epochs 3 \
  --lr 1e-5 \
  --dropout 0.4
# Out:
# Using device: cuda
# Classes: ['fake', 'real']
# Train size: 9000
# Val size: 1000
# model.safetensors: 100%|█████████████████████| 110M/110M [00:04<00:00, 24.2MB/s]
# Saved best model to /kaggle/working/checkpoints/best_model.pth
# Epoch [1/8] | Train Loss: 0.7043 | Train Acc: 0.5290 | Train F1: 0.4887 | Train AUC: 0.5472 | Val Loss: 0.6355 | Val Acc: 0.6900 | Val F1: 0.7285 | Val AUC: 0.7662 | Time: 306.6s
# Saved best model to /kaggle/working/checkpoints/best_model.pth
# Epoch [2/8] | Train Loss: 0.6686 | Train Acc: 0.5908 | Train F1: 0.5764 | Train AUC: 0.6235 | Val Loss: 0.5987 | Val Acc: 0.7130 | Val F1: 0.7493 | Val AUC: 0.7972 | Time: 253.7s
# Saved best model to /kaggle/working/checkpoints/best_model.pth
# Epoch [3/8] | Train Loss: 0.6416 | Train Acc: 0.6288 | Train F1: 0.6200 | Train AUC: 0.6810 | Val Loss: 0.5567 | Val Acc: 0.7360 | Val F1: 0.7533 | Val AUC: 0.8130 | Time: 254.4s
# Unfreezing both CoAtNet + PVTv2 branches
# ...

# %%
# !ls /kaggle/working/checkpoints
# Out:
# best_model.pth

# %%
# !zip -j /kaggle/working/best_model.zip /kaggle/working/checkpoints/best_model.pth
# Out:
#   adding: best_model.pth (deflated 7%)

# %%
# !ls /kaggle/working
# Out:
# best_model.zip	EE4002R-Deepfake-detection-Model
# checkpoints	__notebook__.ipynb
